# %%
text= "i am a Good Student. I am in Delhi"

# %%
#STEP 1: Import Required Libraries

#

import re

import nltk

from nltk.corpus import stopwords

from nltk.tokenize import word_tokenize

from nltk.stem import PorterStemmer, WordNetLemmatizer

#Download required resources (run once)

nltk.download('punkt')

nltk.download('stopwords')

nltk.download('wordnet')

nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
#-------------------------------
#step 2: simple text
#-------------------------------
text=" natural Language is amazing! It hepls machines understand human language."

# %%
#----------------------------------------
#step 3: text cleaning
#----------------------------------------
clean_text=re.sub(r'[^a-zA-Z]',' ',text).lower()
clean_text
# Out:
# ' natural language is amazing  it hepls machines understand human language '

# %%
#----------------------------------
#step 4: Tocknization
#----------------------------------
tokens=word_tokenize(clean_text)
tokens
# Out:
# ['natural',
#  'language',
#  'is',
#  'amazing',
#  'it',
#  'hepls',
#  'machines',
#  'understand',
#  'human',
#  'language']

# %%
#------------------------------------
#step 5: stopword removal
#------------------------------------
stop_words=  set(stopwords.words('english'))
filtered_tokens=[word for word in tokens if word not in stop_words]
filtered_tokens
# Out:
# ['natural',
#  'language',
#  'amazing',
#  'hepls',
#  'machines',
#  'understand',
#  'human',
#  'language']

# %%
#----------------------------------
#Step 6: stemming
#----------------------------------
stemmer=PorterStemmer()
stemmed_words=[stemmer.stem(word) for word in filtered_tokens]
stemmed_words
# Out:
# ['natur',
#  'languag',
#  'amaz',
#  'hepl',
#  'machin',
#  'understand',
#  'human',
#  'languag']

# %%
#-----------------------------
#step 7: Lemmatization
#-----------------------------
lemmatizer= WordNetLemmatizer()
lemmatized_words=[lemmatizer.lemmatize(word) for word in filtered_tokens]
lemmatized_words
# Out:
# ['natural',
#  'language',
#  'amazing',
#  'hepls',
#  'machine',
#  'understand',
#  'human',
#  'language']

# %%
#---------------------------------
# OUTPUT
#---------------------------------
print("Original Text:", text)

print("Clean Text:", clean_text)

print("Tokens:", tokens)

print("After Stopword Removal:", filtered_tokens)

print("Stemmed Words:", stemmed_words)

print("Lemmatized Words:", lemmatized_words)
# Out:
# Original Text:  natural Language is amazing! It hepls machines understand human language.
# Clean Text:  natural language is amazing  it hepls machines understand human language
# Tokens: ['natural', 'language', 'is', 'amazing', 'it', 'hepls', 'machines', 'understand', 'human', 'language']
# After Stopword Removal: ['natural', 'language', 'amazing', 'hepls', 'machines', 'understand', 'human', 'language']
# Stemmed Words: ['natur', 'languag', 'amaz', 'hepl', 'machin', 'understand', 'human', 'languag']
# Lemmatized Words: ['natural', 'language', 'amazing', 'hepls', 'machine', 'understand', 'human', 'language']
