# %%
# Responsible AI
# ➤ Definition

# Responsible AI refers to the design, development, and deployment of AI systems in a way that is safe, ethical, transparent, and accountable.

# ➤ Key Principles

# • Fairness
# AI should not discriminate based on gender, caste, race, or other attributes.
# Example: A hiring AI should not favor one group over another.

# • Transparency
# AI decisions should be understandable.
# Example: A loan approval system should explain why a loan was rejected.

# • Accountability
# There must be someone responsible for AI decisions.
# Example: Companies must take responsibility if AI makes harmful decisions.

# • Privacy & Security
# User data should be protected.
# Example: AI systems should follow data protection laws like GDPR.

# • Reliability & Safety
# AI should work consistently and avoid harmful outcomes.
# Example: Self-driving cars must operate safely in all conditions


# Core Ethical Values

# • Beneficence (Do Good)
# AI should benefit humans and society.

# • Non-Maleficence (Do No Harm)
# Avoid causing harm through AI decisions.

# • Autonomy
# Humans should have control over AI decisions.

# • Justice
# Equal and fair treatment for all users.

# • Explicability
# AI systems should be explainable and interpretable.
