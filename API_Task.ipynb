# %%
# !pip install -q -U google-genai

# %%
from google import genai


client = genai.Client(api_key="API KEY")

chat = client.chats.create(
    model="gemini-2.5-flash",
    config={
        "system_instruction": """You are an expert at teaching science to kids.
Your task is to engage in conversations about science and answer questions.
Explain scientific concepts so that they are easily understandable.
Use analogies and examples that are relatable.
Use humor and make the conversation both educational and interesting.
Ask questions so that you can better understand the user and improve the educational experience.
Suggest ways that these concepts can be related to the real world with observations and experiments."""
    }
)

print("🤖 Science Teacher Bot (type 'exit' to stop)\n")

while True:
    user_input = input("You: ")

    if user_input.lower() == "exit":
        print("Bot: Bye 👋")
        break

    response = chat.send_message(user_input)
    print("Bot:", response.text)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_708/990282407.py in <cell line: 0>()
#       1 from google import genai
#       2
# ----> 3 client = genai.Client()
#       4
#       5 response = client.models.generate_content(
#
# /usr/local/lib/python3.12/dist-packages/google/genai/client.py in __init__(self, vertexai, api_key, credentials, project, location, debug_config, http_options)
#     424       else:
#     425         http_options = HttpOptions(base_url=base_url)
# --> 426
#     427     self._api_client = self._get_api_client(
#     428         vertexai=vertexai,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/client.py in _get_api_client(vertexai, api_key, credentials, project, location, debug_config, http_options)
#     472           http_options=http_options,
#     473       )
# --> 474
#     475     return BaseApiClient(
# ...
